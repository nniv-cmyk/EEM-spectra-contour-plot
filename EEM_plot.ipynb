# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('D:\Research\Eggplant\EggplantEEM\csv\B1M.csv')

# %%
# import numpy as np

# # Replace NaN values with 0
# df.fillna(0, inplace=True)

# # Replace Inf values with a large finite number
# df.replace([np.inf, -np.inf], np.finfo(np.float).max, inplace=True)

# %%
# eem_data = df.iloc[1:, 1:].values
# print(np.isnan(eem_data).any())
# print(np.isinf(eem_data).any())

# %%
# print(eem_data.shape)

# %%
df.iloc[0:, 1:]
# Out:
#            200        205       210      215      220      225      230  \
# 0    -2.402170  -2.475090   0.00000  0.00000  0.00000  0.00000  0.00000
# 1     0.519191  -0.705088   0.00000  0.00000  0.00000  0.00000  0.00000
# 2    -1.298700  -1.614740   0.00000  0.00000  0.00000  0.00000  0.00000
# 3    -1.050830  -1.108110   0.00000  0.00000  0.00000  0.00000  0.00000
# 4     1.851380  -1.264060   0.00000  0.00000  0.00000  0.00000  0.00000
# ..         ...        ...       ...      ...      ...      ...      ...
# 496  17.307200   7.144010   7.50318  5.86377  2.93452  2.12337  1.04962
# 497  18.051800  13.359300  10.21160  5.13063  2.65164  1.68490  2.02774
# 498  22.857400  11.813700   9.51499  4.93468  3.40784  2.27113  1.81723
# 499  17.631300  15.528900   9.94341  4.78335  3.80708  2.51539  1.91818
# 500  25.747900  16.763300   9.69781  4.15410  3.73266  2.30905  2.28364
#
#           235       240       245  ...       555       560       565  \
# ...

# %%
df.columns[1], df.columns[-1]
# Out:
# ('200', '600')

# %%
df = df.sort_values(by=df.columns[0])
df
# Out:
#      Unnamed: 0        200        205       210      215      220      225  \
# 0           215  -2.402170  -2.475090   0.00000  0.00000  0.00000  0.00000
# 1           216   0.519191  -0.705088   0.00000  0.00000  0.00000  0.00000
# 2           217  -1.298700  -1.614740   0.00000  0.00000  0.00000  0.00000
# 3           218  -1.050830  -1.108110   0.00000  0.00000  0.00000  0.00000
# 4           219   1.851380  -1.264060   0.00000  0.00000  0.00000  0.00000
# ..          ...        ...        ...       ...      ...      ...      ...
# 496         711  17.307200   7.144010   7.50318  5.86377  2.93452  2.12337
# 497         712  18.051800  13.359300  10.21160  5.13063  2.65164  1.68490
# 498         713  22.857400  11.813700   9.51499  4.93468  3.40784  2.27113
# 499         714  17.631300  15.528900   9.94341  4.78335  3.80708  2.51539
# 500         715  25.747900  16.763300   9.69781  4.15410  3.73266  2.30905
#
# ...

# %%
df.iloc[0:,0].values[0], df.iloc[1:,0].values[-1]
# Out:
# (215, 715)

# %%
float(df.columns[1]), float(df.columns[-1])
# Out:
# (200.0, 600.0)

# %%
plt.figure(figsize=(12,8))

plt.imshow(np.transpose(df.iloc[:,1:].values)[::-1], cmap='jet', extent=[df.iloc[0:,0].values[0], df.iloc[1:,0].values[-1],
                                                      float(df.columns[1]), float(df.columns[-1])],vmin=0, vmax=8)
plt.grid(False)

plt.gca().xaxis.set_tick_params(labelsize=12)
plt.gca().yaxis.set_tick_params(labelsize=12)

plt.xlabel('Emission wavelength (nm)', fontname='Garamond' ,fontsize=16)
plt.ylabel('Excitation wavelength (nm)', fontname='Garamond', fontsize=16)
plt.title('Fluorescence Excitation-Emission Matrix',fontname='Garamond', fontsize = 20)
plt.colorbar()
plt.show()
